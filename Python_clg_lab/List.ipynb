# %%
mark=[25,12,26,37]
print(mark[0])
# Out:
# 25

# %%
mark=[25,12,26,37]
mark.append(40)
print(mark)
# Out:
# [25, 12, 26, 37, 40]

# %%
num=(2,4,6,8,10)
print(num[2])
# Out:
# 6

# %%
a=[2,6,5,6,7,8]
b=set(a)
print(b)
# Out:
# {2, 5, 6, 7, 8}

# %%
marklist={"Name":"Navas","Age":22,"Mark":30}
print(marklist["Name"])
# Out:
# Navas

# %%
Name="Navas"
print("first element" ,Name[0])
print("second element" ,Name[-1])
# Out:
#   File "C:\Users\PROGRA~1\AppData\Local\Temp/ipykernel_8924/4000887738.py", line 2
#     print("first element" Name[0])
#                           ^
# SyntaxError: invalid syntax
